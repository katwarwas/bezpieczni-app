# %%
import pandas as pd
import numpy as np 
df = pd.read_csv('cyberattacks_database.csv')
#checking data
df.head()
# Out:
#                slug  event_date                       actor  actor_type  \
# 0  babb843cbce5db9e  2023-12-31                Undetermined    Criminal
# 1  581e011d5c37c281  2023-12-31  Belarusian Cyber-Partisans  Hacktivist
# 2  fa79c150aac3cf77  2023-12-30                  INC Ransom    Criminal
# 3  4d12747a4dd52156  2023-12-30                     Irleaks    Criminal
# 4  1079752e8fe90b4d  2023-12-29                Undetermined    Criminal
#
#                           organization  industry_code  \
# 0         Radioactive Waste Management             56
# 1                                BelTA             51
# 2             Xerox Business Solutions             56
# 3                            SnappFood             72
# 4  Memorial University of Newfoundland             61
#
#                                             industry        motive  \
# 0  Administrative and Support and Waste Managemen...  Undetermined
# 1                                        Information       Protest
# 2  Administrative and Support and Waste Managemen...     Financial
# 3                    Accommodation and Food Services     Financial
# 4                               Educational Services     Financial
#
#      event_type                       event_subtype  \
# 0  Undetermined                        Undetermined
# 1    Disruptive                        Undetermined
# 2         Mixed  Exploitation of Application Server
# 3         Mixed  Exploitation of Application Server
# 4    Disruptive                        Undetermined
#
#                                          description  \
# 0  Threat actors try to break into Radioactive Wa...
# 1  Belarusian hacktivists from the Belarusian Cyb...
# 2  The U.S. division of Xerox Business Solutions ...
# 3  Irleaks claims to have broken into the systems...
# 4  Memorial University of Newfoundland (MUN) is h...
#
#                                           source_url  \
# 0  https://www.theguardian.com/business/2023/dec/...
# 1  https://www.bankinfosecurity.com/hacktivists-s...
# 2  https://www.bleepingcomputer.com/news/security...
# 3  https://www.darkreading.com/cyberattacks-data-...
# 4  https://www.bleepingcomputer.com/news/security...
#
#                                              country actor_country
# 0  United Kingdom of Great Britain and Northern I...  Undetermined
# 1                                            Belarus       Belarus
# 2                           United States of America  Undetermined
# 3                         Iran (Islamic Republic of)  Undetermined
# 4                                             Canada  Undetermined

# %%
#checking latest data
df.tail()
# Out:
#                    slug  event_date                   actor  actor_type  \
# 13403  6100014f6ca84b3d  2014-01-02            Undetermined    Criminal
# 13404  1f72c2eb8ab303e4  2014-01-01            Undetermined    Criminal
# 13405  ecac8b3e60a2f72f  2014-01-01            Undetermined    Criminal
# 13406  3bbe0695e2d019f3  2014-01-01  Syrian Electronic Army  Hacktivist
# 13407  231d0b6dbd7db682  1969-12-31            Undetermined    Criminal
#
#                                   organization  industry_code  \
# 13403                                 Snapchat             51
# 13404                         Barry University             61
# 13405                        Record Assist LLC             54
# 13406                     Skype's Social Media             54
# 13407  Shin Bet veterans' association (Shoval)             81
#
#                                                industry        motive  \
# 13403                                       Information  Undetermined
# 13404                              Educational Services  Undetermined
# 13405  Professional, Scientific, and Technical Services  Undetermined
# 13406  Professional, Scientific, and Technical Services       Protest
# 13407     Other Services (except Public Administration)  Undetermined
#
#        event_type                       event_subtype  \
# 13403  Exploitive  Exploitation of Application Server
# 13404  Exploitive           Exploitation of End Hosts
# 13405  Exploitive  Exploitation of Application Server
# 13406  Disruptive                Message Manipulation
# 13407  Exploitive  Exploitation of Application Server
#
#                                              description  \
# 13403  Greyhat hackers publish the partial phone numb...
# 13404  Barry University notifies patients of its Foot...
# 13405  Record Assist LLC notifies of an unauthorized ...
# 13406  The Syrian Electronic Army hacks Skype's Twitt...
# 13407  An unknown entity breaches the website of the ...
#
#                                               source_url  \
# 13403  http://arstechnica.com/security/2014/01/greyha...
# 13404  https://www.beckershospitalreview.com/healthca...
# 13405  https://privacyrights.org/data-breaches/record...
# 13406  http://thenextweb.com/microsoft/2014/01/01/sky...
# 13407  https://www.databreaches.net/hackers-breach-is...
#
#                         country         actor_country
# 13403  United States of America          Undetermined
# 13404  United States of America          Undetermined
# 13405  United States of America          Undetermined
# 13406  United States of America  Syrian Arab Republic
# 13407                    Israel          Undetermined

# %%
#cleaning data 
df = df[df['event_date'] != "1969-12-31"]
df.tail()
# Out:
#                    slug  event_date                   actor    actor_type  \
# 13402  1389e2776dea37ba  2014-01-03           DERP Trolling  Undetermined
# 13403  6100014f6ca84b3d  2014-01-02            Undetermined      Criminal
# 13404  1f72c2eb8ab303e4  2014-01-01            Undetermined      Criminal
# 13405  ecac8b3e60a2f72f  2014-01-01            Undetermined      Criminal
# 13406  3bbe0695e2d019f3  2014-01-01  Syrian Electronic Army    Hacktivist
#
#                organization  industry_code  \
# 13402        World of Tanks             51
# 13403              Snapchat             51
# 13404      Barry University             61
# 13405     Record Assist LLC             54
# 13406  Skype's Social Media             54
#
#                                                industry        motive  \
# 13402                                       Information  Undetermined
# 13403                                       Information  Undetermined
# 13404                              Educational Services  Undetermined
# 13405  Professional, Scientific, and Technical Services  Undetermined
# 13406  Professional, Scientific, and Technical Services       Protest
#
#        event_type                       event_subtype  \
# 13402  Disruptive          External Denial of Service
# 13403  Exploitive  Exploitation of Application Server
# 13404  Exploitive           Exploitation of End Hosts
# 13405  Exploitive  Exploitation of Application Server
# 13406  Disruptive                Message Manipulation
#
#                                              description  \
# 13402  The servers for Steam, Origin, Battle.net, and...
# 13403  Greyhat hackers publish the partial phone numb...
# 13404  Barry University notifies patients of its Foot...
# 13405  Record Assist LLC notifies of an unauthorized ...
# 13406  The Syrian Electronic Army hacks Skype's Twitt...
#
#                                               source_url  \
# 13402  http://arstechnica.com/gaming/2014/01/multiple...
# 13403  http://arstechnica.com/security/2014/01/greyha...
# 13404  https://www.beckershospitalreview.com/healthca...
# 13405  https://privacyrights.org/data-breaches/record...
# 13406  http://thenextweb.com/microsoft/2014/01/01/sky...
#
#                         country         actor_country
# 13402  United States of America          Undetermined
# 13403  United States of America          Undetermined
# 13404  United States of America          Undetermined
# 13405  United States of America          Undetermined
# 13406  United States of America  Syrian Arab Republic

# %%
unique_countries = df['country'].unique()
# sorted_countries = sorted(unique_countries)
# sorted_countries
# check 
for country in unique_countries:
    if not isinstance(country, str):
        print('country:', country )
    

filtered_df = df[~df['country'].apply(lambda x: not isinstance(x, str))]
filtered_df

unique_countries = filtered_df['country'].unique()
sorted_countries = sorted(unique_countries)
sorted_countries
# Out:
# country: nan
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Bermuda',
#  'Bolivia (Plurinational State of)',
#  'Bonaire, Sint Eustatius and Saba',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Cabo Verde',
#  'Cambodia',
#  'Canada',
#  'Cayman Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Guiana',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Holy See',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran (Islamic Republic of)',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  "Korea (the Democratic People's Republic of)",
#  'Korea (the Republic of)',
#  'Kuwait',
#  "Lao People's Democratic Republic",
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Mexico',
#  'Moldova (the Republic of)',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Nigeria',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palau',
#  'Palestine, State of',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Qatar',
#  'Republic of North Macedonia',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saint Vincent and the Grenadines',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic',
#  'Taiwan (Province of China)',
#  'Tajikistan',
#  'Tanzania, United Republic of',
#  'Thailand',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'Undetermined',
#  'United Arab Emirates',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
most_attacked_country = {}
for country in sorted_countries:
    count = (df['country'] == country).sum()
    if count > 100:
        most_attacked_country[country] = count
print(most_attacked_country)
most_attacked_country.pop('Undetermined', None)
most_attacked_country
# Out:
# {'Australia': 251, 'Brazil': 145, 'Canada': 345, 'China': 156, 'France': 249, 'Germany': 229, 'India': 316, 'Israel': 191, 'Italy': 409, 'Japan': 149, 'Poland': 128, 'Russian Federation': 370, 'Ukraine': 383, 'Undetermined': 359, 'United Kingdom of Great Britain and Northern Ireland': 729, 'United States of America': 6479}
# {'Australia': 251,
#  'Brazil': 145,
#  'Canada': 345,
#  'China': 156,
#  'France': 249,
#  'Germany': 229,
#  'India': 316,
#  'Israel': 191,
#  'Italy': 409,
#  'Japan': 149,
#  'Poland': 128,
#  'Russian Federation': 370,
#  'Ukraine': 383,
#  'United Kingdom of Great Britain and Northern Ireland': 729,
#  'United States of America': 6479}

# %%
translations = {
    'Australia': 'Australia',
    'Brazil': 'Brazylia',
    'Canada': 'Kanada',
    'China': 'Chiny',
    'France': 'Francja',
    'Germany': 'Niemcy',
    'India': 'Indie',
    'Israel': 'Izrael',
    'Italy': 'Włochy',
    'Japan': 'Japonia',
    'Poland': 'Polska',
    'Russian Federation': 'Rosja',
    'Ukraine': 'Ukraina',
    'United Kingdom of Great Britain and Northern Ireland': 'Wielka Brytania',
    'United States of America': 'Stany Zjednoczone'
}
most_attacked_country_polish = {translations[country]: count for country, count in most_attacked_country.items() if country in translations}
most_attacked_country_polish_sorted = dict(sorted(most_attacked_country_polish.items(), key=lambda item: item[1], reverse=True))
most_attacked_country_polish_sorted
# Out:
# {'Stany Zjednoczone': 6479,
#  'Wielka Brytania': 729,
#  'Włochy': 409,
#  'Ukraina': 383,
#  'Rosja': 370,
#  'Kanada': 345,
#  'Indie': 316,
#  'Australia': 251,
#  'Francja': 249,
#  'Niemcy': 229,
#  'Izrael': 191,
#  'Chiny': 156,
#  'Japonia': 149,
#  'Brazylia': 145,
#  'Polska': 128}

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch



fig, ax = plt.subplots(figsize=(15,12))
fig.patch.set_facecolor('#292e47')

plt.subplots_adjust(bottom=0.25)

labels = list(most_attacked_country_polish_sorted.keys())  
values = list(most_attacked_country_polish_sorted.values())
bars = ax.bar(labels, values, color='#4f63a6')

ax.set_frame_on(False)
ax.set_ylabel('Liczba ataków', color='#e4eaf5', fontsize=20)
ax.set_title('Najczęściej atakowane kraje', color='#e4eaf5', fontsize=28, pad=40)

ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels, color='#e4eaf5', rotation=45, ha='right', fontsize=15)
ax.tick_params(axis='x', colors='#e4eaf5', labelsize=16)
ax.tick_params(axis='y', colors='#e4eaf5', labelsize=12)

ax.set_ylim(0, 1000)

for bar in bars:
    yval = bar.get_height()
    if yval < 1000:
        ax.text(bar.get_x() + bar.get_width()/2, yval, f'{yval}', va='bottom', ha='center', color='#e4eaf5', fontsize=16)
    else: 
        ax.text(bar.get_x() + bar.get_width()/2, 960, f'{yval}', va='bottom', ha='center', color='#e4eaf5', fontweight=600, fontsize=14)

plt.savefig('most_attaked_country')
plt.show()

# %%
filtered_df.head()
# Out:
#                slug  event_date                       actor  actor_type  \
# 0  babb843cbce5db9e  2023-12-31                Undetermined    Criminal
# 1  581e011d5c37c281  2023-12-31  Belarusian Cyber-Partisans  Hacktivist
# 2  fa79c150aac3cf77  2023-12-30                  INC Ransom    Criminal
# 3  4d12747a4dd52156  2023-12-30                     Irleaks    Criminal
# 4  1079752e8fe90b4d  2023-12-29                Undetermined    Criminal
#
#                           organization  industry_code  \
# 0         Radioactive Waste Management             56
# 1                                BelTA             51
# 2             Xerox Business Solutions             56
# 3                            SnappFood             72
# 4  Memorial University of Newfoundland             61
#
#                                             industry        motive  \
# 0  Administrative and Support and Waste Managemen...  Undetermined
# 1                                        Information       Protest
# 2  Administrative and Support and Waste Managemen...     Financial
# 3                    Accommodation and Food Services     Financial
# 4                               Educational Services     Financial
#
#      event_type                       event_subtype  \
# 0  Undetermined                        Undetermined
# 1    Disruptive                        Undetermined
# 2         Mixed  Exploitation of Application Server
# 3         Mixed  Exploitation of Application Server
# 4    Disruptive                        Undetermined
#
#                                          description  \
# 0  Threat actors try to break into Radioactive Wa...
# 1  Belarusian hacktivists from the Belarusian Cyb...
# 2  The U.S. division of Xerox Business Solutions ...
# 3  Irleaks claims to have broken into the systems...
# 4  Memorial University of Newfoundland (MUN) is h...
#
#                                           source_url  \
# 0  https://www.theguardian.com/business/2023/dec/...
# 1  https://www.bankinfosecurity.com/hacktivists-s...
# 2  https://www.bleepingcomputer.com/news/security...
# 3  https://www.darkreading.com/cyberattacks-data-...
# 4  https://www.bleepingcomputer.com/news/security...
#
#                                              country actor_country
# 0  United Kingdom of Great Britain and Northern I...  Undetermined
# 1                                            Belarus       Belarus
# 2                           United States of America  Undetermined
# 3                         Iran (Islamic Republic of)  Undetermined
# 4                                             Canada  Undetermined

# %%
from datetime import datetime
from datetime import datetime
date_str= np.array(filtered_df['event_date'])

# Funkcja do przekształcenia stringa w datę
def string_to_date(date_str):
    return datetime.strptime(date_str, "%Y-%m-%d").date()

# Wektorowe przekształcenie całej tablicy
vectorized_string_to_date = np.vectorize(string_to_date)
dates = vectorized_string_to_date(date_str)
dates
# Out:
# array([datetime.date(2023, 12, 31), datetime.date(2023, 12, 31),
#        datetime.date(2023, 12, 30), ..., datetime.date(2014, 1, 1),
#        datetime.date(2014, 1, 1), datetime.date(2014, 1, 1)], dtype=object)

# %%
year_event = dates.astype('datetime64[Y]')
year_events = year_event.astype('str')
year_events_name = np.unique(year_events)
year_events_count = pd.DataFrame(pd.DataFrame(year_events).value_counts()).sort_index().values

# %%
fig, ax = plt.subplots(figsize=(15,12))
fig.patch.set_facecolor('#292e47')
ax.plot(year_events_name, year_events_count, marker = 'o', color='#4f63a6', linewidth=3, markersize=15, linestyle='--')

plt.subplots_adjust(bottom=0.1)

ax.set_frame_on(False)

ax.set_xlabel('Rok', color='#e4eaf5', fontsize=20, labelpad=20)
ax.set_ylabel('Liczba ataków', color='#e4eaf5', fontsize=20, labelpad=20)
ax.tick_params(axis='both', colors='#e4eaf5')
ax.set_ylim(0, 3000)

ax.tick_params(axis='x', labelsize=12) 
ax.tick_params(axis='y', labelsize=12)

plt.title('Liczba ataków w danym roku', fontsize=28, color='#e4eaf5', pad=40)

for (x, y) in zip(year_events_name, year_events_count):
    number = str(y)[1:-1]
    ax.text(x , y + 100, number, color='#e4eaf5', ha='center', fontsize=12, fontweight=800)
    
plt.savefig('number_of_events_by_year')
plt.show()

# %%
import math
motive = dict(filtered_df['motive'].value_counts()[filtered_df['motive'].value_counts() > 1]) 

translations = {
    'Financial': 'Finansowy',
    'Protest': 'Protest',
    'Political-Espionage': 'Szpiegostwo polityczne',
    'Sabotage': 'Sabotaż',
    'Personal Attack': 'Atak osobisty',
    'Industrial-Espionage': 'Szpiegostwo przemysłowe',
    'Espionage': 'Szpiegostwo',
    'Undetermined': 'Nieokreślony'
}


motive_pl = {translations[key]: value for key, value in motive.items() if key != 'Undetermined'}
motive_pl['Nieokreślony'] = motive['Undetermined']

total = sum(motive_pl.values())
percentages = [f"{(value / total) * 200/ 2:.1f}%" for value in motive_pl.values()]

labels = [f"{key} ~ {value}" for key, value in zip(motive_pl.keys(), percentages)]


labels
# Out:
# ['Finansowy ~ 56.3%',
#  'Protest ~ 12.1%',
#  'Szpiegostwo polityczne ~ 4.6%',
#  'Sabotaż ~ 2.4%',
#  'Atak osobisty ~ 0.7%',
#  'Szpiegostwo przemysłowe ~ 0.7%',
#  'Szpiegostwo ~ 0.2%',
#  'Nieokreślony ~ 23.1%']

# %%
fig, ax = plt.subplots(figsize=(15,12))
fig.patch.set_facecolor('#292e47')

def make_autopct(values):
    def my_autopct(pct):
        value = int(round(pct*total/100.0))
        rounded_pct = math.floor(pct * 2) / 2
        return f'{pct:.1f}%' if value > total * 0.01 else ''  
    return my_autopct

ax.pie(motive_pl.values(), pctdistance=0.8, autopct=make_autopct(motive_pl.values()), colors=['#3b466d', '#4f63a6', '#5a74b6',  '#6d8bc4', '#89a6d1', '#afc5e1', '#d0dced', '#455388'], startangle=45, textprops={'color':'#e4eaf5', 'fontsize':14})

circle = plt.Circle((0, 0), 0.60, fc='#292e47')
ax.add_artist(circle)
plt.title('Motywy Cyberataków', fontsize=28, color='#e4eaf5' )
plt.legend(labels, loc='center', framealpha=0.3, fontsize=12, labelcolor = '#e4eaf5')
plt.savefig('cyber_attack_motives')
plt.show()

# %%
filtered_df.head()
# Out:
#                slug  event_date                       actor  actor_type  \
# 0  babb843cbce5db9e  2023-12-31                Undetermined    Criminal
# 1  581e011d5c37c281  2023-12-31  Belarusian Cyber-Partisans  Hacktivist
# 2  fa79c150aac3cf77  2023-12-30                  INC Ransom    Criminal
# 3  4d12747a4dd52156  2023-12-30                     Irleaks    Criminal
# 4  1079752e8fe90b4d  2023-12-29                Undetermined    Criminal
#
#                           organization  industry_code  \
# 0         Radioactive Waste Management             56
# 1                                BelTA             51
# 2             Xerox Business Solutions             56
# 3                            SnappFood             72
# 4  Memorial University of Newfoundland             61
#
#                                             industry        motive  \
# 0  Administrative and Support and Waste Managemen...  Undetermined
# 1                                        Information       Protest
# 2  Administrative and Support and Waste Managemen...     Financial
# 3                    Accommodation and Food Services     Financial
# 4                               Educational Services     Financial
#
#      event_type                       event_subtype  \
# 0  Undetermined                        Undetermined
# 1    Disruptive                        Undetermined
# 2         Mixed  Exploitation of Application Server
# 3         Mixed  Exploitation of Application Server
# 4    Disruptive                        Undetermined
#
#                                          description  \
# 0  Threat actors try to break into Radioactive Wa...
# 1  Belarusian hacktivists from the Belarusian Cyb...
# 2  The U.S. division of Xerox Business Solutions ...
# 3  Irleaks claims to have broken into the systems...
# 4  Memorial University of Newfoundland (MUN) is h...
#
#                                           source_url  \
# 0  https://www.theguardian.com/business/2023/dec/...
# 1  https://www.bankinfosecurity.com/hacktivists-s...
# 2  https://www.bleepingcomputer.com/news/security...
# 3  https://www.darkreading.com/cyberattacks-data-...
# 4  https://www.bleepingcomputer.com/news/security...
#
#                                              country actor_country
# 0  United Kingdom of Great Britain and Northern I...  Undetermined
# 1                                            Belarus       Belarus
# 2                           United States of America  Undetermined
# 3                         Iran (Islamic Republic of)  Undetermined
# 4                                             Canada  Undetermined

# %%
sorted_actor_countries = sorted(filtered_df['actor_country'].unique())
most_actor_countries = {}
for country in sorted_actor_countries:
    count = (df['actor_country'] == country).sum()
    if count > 50:
        most_actor_countries[country] = count
most_actor_countries.pop('Undetermined', None)
print(most_actor_countries)
translations = {
    'Azerbaijan': 'Azerbejdżan',
    'China': 'Chiny',
    'India': 'Indie',
    'Iran (Islamic Republic of)': 'Iran',
    "Korea (the Democratic People's Republic of)": 'Korea Północna',
    'Pakistan': 'Pakistan',
    'Russian Federation': 'Rosja',
    'Saudi Arabia': 'Arabia Saudyjska',
    'Syrian Arab Republic': 'Syria',
    'Ukraine': 'Ukraina',
    'United Kingdom of Great Britain and Northern Ireland': 'Wielka Brytania',
    'United States of America': 'Stany Zjednoczone'
}

most_actor_countries_pl = {translations[key]: value for key, value in most_actor_countries.items()}
most_actor_countries_pl_sorted = dict(sorted(most_actor_countries_pl.items(), key=lambda item: item[1], reverse=True))

most_actor_countries_pl_sorted
# Out:
# {'Azerbaijan': 68, 'China': 157, 'India': 68, 'Iran (Islamic Republic of)': 87, "Korea (the Democratic People's Republic of)": 149, 'Pakistan': 61, 'Russian Federation': 1741, 'Saudi Arabia': 87, 'Syrian Arab Republic': 58, 'Ukraine': 125, 'United Kingdom of Great Britain and Northern Ireland': 51, 'United States of America': 139}
# {'Rosja': 1741,
#  'Chiny': 157,
#  'Korea Północna': 149,
#  'Stany Zjednoczone': 139,
#  'Ukraina': 125,
#  'Iran': 87,
#  'Arabia Saudyjska': 87,
#  'Azerbejdżan': 68,
#  'Indie': 68,
#  'Pakistan': 61,
#  'Syria': 58,
#  'Wielka Brytania': 51}

# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(15,12))
fig.patch.set_facecolor('#292e47')

plt.subplots_adjust(bottom=0.25)

labels = list(most_actor_countries_pl_sorted.keys())  
values = list(most_actor_countries_pl_sorted.values())
bars = ax.bar(labels, values, color='#4f63a6')

ax.set_frame_on(False)
ax.set_ylabel('Liczba ataków', color='#e4eaf5', fontsize=20)
ax.set_title('Najczęściej atakujące kraje', color='#e4eaf5', fontsize=28, pad=40)

ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels, color='#e4eaf5', rotation=45, ha='right', fontsize=15)
ax.tick_params(axis='x', colors='#e4eaf5', labelsize=16)
ax.tick_params(axis='y', colors='#e4eaf5', labelsize=12)

ax.set_ylim(0, 400)

for bar in bars:
    yval = bar.get_height()
    if yval < 1000:
        ax.text(bar.get_x() + bar.get_width()/2, yval, f'{yval}', va='bottom', ha='center', color='#e4eaf5', fontsize=16)
    else: 
        ax.text(bar.get_x() + bar.get_width()/2, 360, f'{yval}', va='bottom', ha='center', color='#e4eaf5', fontweight=600, fontsize=14)

plt.savefig('most_actor_country')
plt.show()

# %%
event_type = dict(filtered_df['event_type'].value_counts()[filtered_df['event_type'].value_counts() > 1]) 

translations = {
    'Exploitive': 'Wykorzystujący',
    'Disruptive': 'Dezorganizujący',
    'Mixed': 'Mieszany',
    'Undetermined': 'Nieokreślony'
}


event_type_pl = {translations[key]: value for key, value in event_type.items() if key != 'Undetermined'}
event_type_pl['Nieokreślony'] = event_type['Undetermined']

total = sum(event_type_pl.values())
percentages = [f"{(value / total) * 200/ 2:.1f}%" for value in event_type_pl.values()]

labels = [f"{key} ~ {value}" for key, value in zip(event_type_pl.keys(), percentages)]


labels
# Out:
# ['Wykorzystujący ~ 49.8%',
#  'Dezorganizujący ~ 31.0%',
#  'Mieszany ~ 17.9%',
#  'Nieokreślony ~ 1.3%']

# %%
fig, ax = plt.subplots(figsize=(15,12))
fig.patch.set_facecolor('#292e47')

ax.pie(event_type_pl.values(), pctdistance=0.8, autopct='%1.1f%%', colors=['#3b466d', '#4f63a6', '#5a74b6',  '#6d8bc4', '#89a6d1', '#afc5e1', '#d0dced', '#455388'], startangle=45, textprops={'color':'#e4eaf5', 'fontsize':14})


circle = plt.Circle((0, 0), 0.60, fc='#292e47')
ax.add_artist(circle)
plt.title('Typy Cyberataków', fontsize=28, color='#e4eaf5' )
plt.legend(labels, loc='center', framealpha=0.3, fontsize=12, labelcolor = '#e4eaf5')
plt.savefig('cyber_attack_event_types')
plt.show()

# %%
filtered_df['actor_type'].unique()
# Out:
# array(['Criminal', 'Hacktivist', 'Nation-State', 'Terrorist',
#        'Undetermined', 'Hobbyist'], dtype=object)

# %%
actor_type = dict(filtered_df['actor_type'].value_counts()[filtered_df['actor_type'].value_counts() > 1]) 

translations = {
    'Criminal': 'Przestępcy',
    'Hacktivist': 'Haktywiści',
    'Nation-State': 'Aktorzy państwowi',
    'Terrorist': 'Terroryści',
    'Undetermined': 'Nieokreśleni',
    'Hobbyist': 'Hobbyści'
}


actor_type_pl = {translations[key]: value for key, value in actor_type.items() if key != 'Undetermined'}
actor_type_pl['Nieokreślony'] = actor_type['Undetermined']

total = sum(actor_type_pl.values())
percentages = [f"{(value / total) * 200/ 2:.1f}%" for value in actor_type_pl.values()]

labels = [f"{key} ~ {value}" for key, value in zip(actor_type_pl.keys(), percentages)]


labels
# Out:
# ['Przestępcy ~ 76.0%',
#  'Haktywiści ~ 13.9%',
#  'Aktorzy państwowi ~ 5.5%',
#  'Hobbyści ~ 1.4%',
#  'Terroryści ~ 0.2%',
#  'Nieokreślony ~ 3.0%']

# %%
fig, ax = plt.subplots(figsize=(15,12))
fig.patch.set_facecolor('#292e47')

def make_autopct(values):
    def my_autopct(pct):
        value = int(round(pct*total/100.0))
        rounded_pct = math.floor(pct * 2) / 2
        return f'{pct:.1f}%' if value > total * 0.01 else ''  
    return my_autopct


ax.pie(actor_type_pl.values(), pctdistance=0.8, autopct=make_autopct(actor_type_pl.values()), colors=['#3b466d', '#4f63a6', '#5a74b6',  '#6d8bc4', '#89a6d1', '#455388'], startangle=45, textprops={'color':'#e4eaf5', 'fontsize':14})



circle = plt.Circle((0, 0), 0.60, fc='#292e47')
ax.add_artist(circle)
plt.title('Aktorzy Cyberataków', fontsize=28, color='#e4eaf5' )
plt.legend(labels, loc='center', framealpha=0.3, fontsize=12, labelcolor = '#e4eaf5')
plt.savefig('cyber_attack_actor_types')
plt.show()

# %%
poland_df = df[df['country'] == 'Poland']
poland_df
# Out:
#                    slug  event_date                       actor    actor_type  \
# 838    5901a9dbf4b129de  2023-08-25         Two Polish citizens    Hacktivist
# 1266   2b1efa352bff4d7d  2023-06-28                Undetermined      Criminal
# 2043   435d94b5f119b516  2023-03-01               NoName057(16)    Hacktivist
# 2164   c5fd1db6d6e1a85c  2023-02-08                    UAC-0114  Nation-State
# 2289   850c22a0c8cf7d3b  2023-01-12            Anonymous Russia    Hacktivist
# ...                 ...         ...                         ...           ...
# 11205  8ec85dee1f5bb7ce  2016-07-15               Pravyy Sector  Undetermined
# 11251  daba6a2329f41d63  2016-07-07               Pravyy Sector  Undetermined
# 12157  b5a7f976fed0cf4c  2015-09-24  NetPirates AKA @TheNetShip  Undetermined
# 12801  9c5afc164ff4ab76  2014-10-24               Islamic State    Hacktivist
# 12979  204844c1e51a4fef  2014-08-14                 CyberBerkut    Hacktivist
#
#                                    organization  industry_code  \
# 838    Poland's railway infrastructure operator             48
# 1266                                     Radeal             51
# 2043                       Poland's tax service             92
# 2164       Unspecified Polish government agency             92
# 2289                     Polish Administrations             92
# ...                                         ...            ...
# 11205                 Poland's Defence Ministry             92
# 11251                                     Netia             51
# 12157                                DressCloud             44
# 12801                     Warsaw Stock Exchange             52
# 12979               Various Government Websites             92
#
#                              industry               motive  event_type  \
# 838    Transportation and Warehousing              Protest  Disruptive
# 1266                      Information            Financial  Exploitive
# 2043            Public Administration              Protest  Exploitive
# 2164            Public Administration  Political-Espionage  Exploitive
# 2289            Public Administration              Protest  Disruptive
# ...                               ...                  ...         ...
# 11205           Public Administration            Financial  Exploitive
# 11251                     Information         Undetermined  Exploitive
# 12157                    Retail Trade         Undetermined  Exploitive
# 12801           Finance and Insurance         Undetermined  Exploitive
# 12979           Public Administration              Protest  Disruptive
#
#                             event_subtype  \
# 838                       Physical Attack
# 1266                         Undetermined
# 2043           External Denial of Service
# 2164             Exploitation of End Host
# 2289          External Denial of Services
# ...                                   ...
# 11205  Exploitation of Application Server
# 11251  Exploitation of Application Server
# 12157  Exploitation of Application Server
# 12801  Exploitation of Application Server
# 12979                Message Manipulation
#
#                                              description  \
# 838    A DDoS attack pro-Russia carried out sending "...
# 1266   Radeal, the Polish developer of the Android st...
# 2043   Poland's tax service website is hit by a DDoS ...
# 2164   Attackers attempt to infect Ukrainian and Poli...
# 2289   Anonymous Russia claims to have conducted DDoS...
# ...                                                  ...
# 11205  This time Pravyy Sector threaten to release da...
# 11251  A Ukrainian hacker going by the handle of Prav...
# 12157  The NetPirates hack dresscloud.pl and dump 5,2...
# 12801  The Warsaw Stock Exchange is allegedly hacked....
# 12979  Pro Russian Hacker collective CyberBerkut defa...
#
#                                               source_url country  \
# 838    https://therecord.media/two-arrested-poland-ra...  Poland
# 1266   https://www.securityweek.com/sensitive-informa...  Poland
# 2043   https://therecord.media/poland-blames-russian-...  Poland
# 2164   https://therecord.media/hackers-used-fake-webs...  Poland
# 2289                           https://t.me/anon_by/2585  Poland
# ...                                                  ...     ...
# 11205  http://news.softpedia.com/news/hackers-steal-d...  Poland
# 11251  https://www.hackread.com/ukranian-hacker-hacks...  Poland
# 12157  https://web.archive.org/web/20151026171936/htt...  Poland
# 12801  http://www.techworm.net/2014/10/warsaw-stock-e...  Poland
# 12979  https://books.google.com/books?id=DrNSDwAAQBAJ...  Poland
#
#             actor_country
# 838          Undetermined
# 1266         Undetermined
# 2043   Russian Federation
# 2164         Undetermined
# 2289   Russian Federation
# ...                   ...
# 11205        Undetermined
# 11251        Undetermined
# 12157        Undetermined
# 12801               Japan
# 12979             Ukraine
#
# [128 rows x 14 columns]

# %%
poland_df['actor_country'].unique()
# Out:
# array(['Undetermined', 'Russian Federation', 'Belarus', 'Brazil', 'Japan',
#        'Ukraine'], dtype=object)

# %%
actor_country = dict(poland_df['actor_country'].value_counts())

translations = {
    'Russian Federation': 'Rosja',
    'Undetermined': 'Nieokreślony',
    'Belarus': 'Białoruś',
    'Brazil': 'Brazylia',
    'Japan': 'Japonia',
    'Ukraine': 'Ukraina'
}

actor_country_pl = {translations[key]: value for key, value in actor_country.items() if key != 'Undetermined'}
actor_country_pl['Nieokreślony'] = actor_country['Undetermined']
actor_country_pl
# Out:
# {'Rosja': 92,
#  'Białoruś': 11,
#  'Brazylia': 1,
#  'Japonia': 1,
#  'Ukraina': 1,
#  'Nieokreślony': 22}

# %%
fig, ax = plt.subplots(figsize=(15,12))
fig.patch.set_facecolor('#292e47')

plt.subplots_adjust(bottom=0.25)

labels = list(actor_country_pl.keys())  
values = list(actor_country_pl.values())
bars = ax.bar(labels, values, color='#4f63a6')

ax.set_frame_on(False)
ax.set_ylabel('Liczba ataków', color='#e4eaf5', fontsize=20)
ax.set_title('Najczęściej atakujące kraje na Polskę', color='#e4eaf5', fontsize=28, pad=40)

ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels, color='#e4eaf5', rotation=45, ha='right', fontsize=15)
ax.tick_params(axis='x', colors='#e4eaf5', labelsize=16)
ax.tick_params(axis='y', colors='#e4eaf5', labelsize=12)

ax.set_ylim(0, 100)

for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, f'{yval}', va='bottom', ha='center', color='#e4eaf5', fontsize=14)

plt.savefig('most_actor_country_poland')
plt.show()

# %%
motive = dict(poland_df['motive'].value_counts())

translations = {
    'Financial': 'Finansowy',
    'Protest': 'Protest',
    'Political-Espionage': 'Szpiegostwo polityczne',
    'Sabotage': 'Sabotaż',
    'Personal Attack': 'Atak osobisty',
    'Industrial-Espionage': 'Szpiegostwo przemysłowe',
    'Espionage': 'Szpiegostwo',
    'Undetermined': 'Nieokreślony'
}


motive_pl = {translations[key]: value for key, value in motive.items() if key != 'Undetermined'}
motive_pl['Nieokreślony'] = motive['Undetermined']

total = sum(motive_pl.values())
percentages = [f"{(value / total) * 200/ 2:.1f}%" for value in motive_pl.values()]

labels = [f"{key} ~ {value}" for key, value in zip(motive_pl.keys(), percentages)]


labels
# Out:
# ['Protest ~ 72.7%',
#  'Finansowy ~ 9.4%',
#  'Sabotaż ~ 8.6%',
#  'Szpiegostwo polityczne ~ 3.1%',
#  'Nieokreślony ~ 6.2%']

# %%
fig, ax = plt.subplots(figsize=(15,12))
fig.patch.set_facecolor('#292e47')

def make_autopct(values):
    def my_autopct(pct):
        value = int(round(pct*total/100.0))
        rounded_pct = math.floor(pct * 2) / 2
        return f'{pct:.1f}%' if value > total * 0.01 else ''  
    return my_autopct

ax.pie(motive_pl.values(), pctdistance=0.8, autopct=make_autopct(motive_pl.values()), colors=['#3b466d', '#4f63a6', '#5a74b6',  '#6d8bc4', '#89a6d1', '#afc5e1', '#d0dced', '#455388'], startangle=45, textprops={'color':'#e4eaf5', 'fontsize':14})

circle = plt.Circle((0, 0), 0.60, fc='#292e47')
ax.add_artist(circle)
plt.title('Motywy Cyberataków na Polskę', fontsize=28, color='#e4eaf5' )
plt.legend(labels, loc='center', framealpha=0.3, fontsize=12, labelcolor = '#e4eaf5')
plt.savefig('cyber_attack_motives_poland')
plt.show()

# %%
filtered_df.head()
# Out:
#                slug  event_date                       actor  actor_type  \
# 0  babb843cbce5db9e  2023-12-31                Undetermined    Criminal
# 1  581e011d5c37c281  2023-12-31  Belarusian Cyber-Partisans  Hacktivist
# 2  fa79c150aac3cf77  2023-12-30                  INC Ransom    Criminal
# 3  4d12747a4dd52156  2023-12-30                     Irleaks    Criminal
# 4  1079752e8fe90b4d  2023-12-29                Undetermined    Criminal
#
#                           organization  industry_code  \
# 0         Radioactive Waste Management             56
# 1                                BelTA             51
# 2             Xerox Business Solutions             56
# 3                            SnappFood             72
# 4  Memorial University of Newfoundland             61
#
#                                             industry        motive  \
# 0  Administrative and Support and Waste Managemen...  Undetermined
# 1                                        Information       Protest
# 2  Administrative and Support and Waste Managemen...     Financial
# 3                    Accommodation and Food Services     Financial
# 4                               Educational Services     Financial
#
#      event_type                       event_subtype  \
# 0  Undetermined                        Undetermined
# 1    Disruptive                        Undetermined
# 2         Mixed  Exploitation of Application Server
# 3         Mixed  Exploitation of Application Server
# 4    Disruptive                        Undetermined
#
#                                          description  \
# 0  Threat actors try to break into Radioactive Wa...
# 1  Belarusian hacktivists from the Belarusian Cyb...
# 2  The U.S. division of Xerox Business Solutions ...
# 3  Irleaks claims to have broken into the systems...
# 4  Memorial University of Newfoundland (MUN) is h...
#
#                                           source_url  \
# 0  https://www.theguardian.com/business/2023/dec/...
# 1  https://www.bankinfosecurity.com/hacktivists-s...
# 2  https://www.bleepingcomputer.com/news/security...
# 3  https://www.darkreading.com/cyberattacks-data-...
# 4  https://www.bleepingcomputer.com/news/security...
#
#                                              country actor_country
# 0  United Kingdom of Great Britain and Northern I...  Undetermined
# 1                                            Belarus       Belarus
# 2                           United States of America  Undetermined
# 3                         Iran (Islamic Republic of)  Undetermined
# 4                                             Canada  Undetermined

# %%
# print(filtered_df['actor_country'].unique())
# print(filtered_df['event_type'].unique())
# print(filtered_df['motive'].unique())
 # print(sorted(filtered_df['country'].unique()))
country = filtered_df['country'][filtered_df['country'] != 'Undetermined']
print(sorted(country.unique()))
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Antarctica', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Bermuda', 'Bolivia (Plurinational State of)', 'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde', 'Cambodia', 'Canada', 'Cayman Islands', 'Chile', 'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'France', 'French Guiana', 'Gabon', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Guadeloupe', 'Guam', 'Guatemala', 'Holy See', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', "Korea (the Democratic People's Republic of)", 'Korea (the Republic of)', 'Kuwait', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Mexico', 'Moldova (the Republic of)', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Nigeria', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Palestine, State of', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Republic of North Macedonia', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Vincent and the Grenadines', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa', 'Spain', 'Sri Lanka', 'Sudan', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan (Province of China)', 'Tajikistan', 'Tanzania, United Republic of', 'Thailand', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom of Great Britain and Northern Ireland', 'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe']

# %%
actor_country_dict = {
    'Undetermined': 'Nieokreślony',
    'Belarus': 'Białoruś',
    'Iran (Islamic Republic of)': 'Iran',
    'Ukraine': 'Ukraina',
    'Israel': 'Izrael',
    'Russian Federation': 'Rosja',
    'India': 'Indie',
    'Palestine, State of': 'Palestyna',
    "Korea (the Democratic People's Republic of)": 'Korea Północna',
    'China': 'Chiny',
    'Yemen': 'Jemen',
    'Pakistan': 'Pakistan',
    'Viet Nam': 'Wietnam',
    'Italy': 'Włochy',
    'Turkey': 'Turcja',
    'Sudan': 'Sudan',
    'Cuba': 'Kuba',
    'Bangladesh': 'Bangladesz',
    'Iraq': 'Irak',
    'United States of America': 'Stany Zjednoczone',
    'Thailand': 'Tajlandia',
    'Malaysia': 'Malezja',
    'Brazil': 'Brazylia',
    'Bolivia (Plurinational State of)': 'Boliwia',
    'Philippines': 'Filipiny',
    'Kenya': 'Kenia',
    'Myanmar': 'Mjanma',
    'Lebanon': 'Liban',
    'France': 'Francja',
    'United Arab Emirates': 'Zjednoczone Emiraty Arabskie',
    'South Africa': 'Południowa Afryka',
    'Australia': 'Australia',
    'United Kingdom of Great Britain and Northern Ireland': 'Wielka Brytania',
    'Syrian Arab Republic': 'Syria',
    'Saudi Arabia': 'Arabia Saudyjska',
    'Greece': 'Grecja',
    'Sierra Leone': 'Sierra Leone',
    'Uzbekistan': 'Uzbekistan',
    'Bulgaria': 'Bułgaria',
    'Togo': 'Togo',
    'Spain': 'Hiszpania',
    'Cambodia': 'Kambodża',
    'Ireland': 'Irlandia',
    'Canada': 'Kanada',
    'Netherlands': 'Holandia',
    'Algeria': 'Algieria',
    'Austria': 'Austria',
    'Venezuela (Bolivarian Republic of)': 'Wenezuela',
    'Panama': 'Panama',
    'Kuwait': 'Kuwejt',
    'Poland': 'Polska',
    'Azerbaijan': 'Azerbejdżan',
    'Germany': 'Niemcy',
    'Czechia': 'Czechy',
    'Rwanda': 'Rwanda',
    'Mexico': 'Meksyk',
    'Jordan': 'Jordania',
    'Portugal': 'Portugalia',
    'Japan': 'Japonia',
    'Chile': 'Chile',
    'Uganda': 'Uganda',
    'Costa Rica': 'Kostaryka',
    'Nigeria': 'Nigeria',
    'Egypt': 'Egipt',
    'Armenia': 'Armenia',
    'Belgium': 'Belgia',
    'Nepal': 'Nepal',
    'Ecuador': 'Ekwador',
    'Sri Lanka': 'Sri Lanka',
    'Morocco': 'Maroko',
    'New Zealand': 'Nowa Zelandia',
    'Indonesia': 'Indonezja',
    'Turkmenistan': 'Turkmenistan',
    'Ghana': 'Ghana',
    'Albania': 'Albania',
    'Romania': 'Rumunia',
    'Norway': 'Norwegia',
    'Denmark': 'Dania',
    'Libya': 'Libia',
    'Afghanistan': 'Afganistan',
    'Korea (the Republic of)': 'Korea Południowa',
    'Peru': 'Peru'
}

filtered_df.loc[:, 'actor_country'] = filtered_df['actor_country'].map(actor_country_dict).fillna(filtered_df['actor_country'])


event_type_dict = {
    'Undetermined': 'Nieokreślony',
    'Disruptive': 'Zakłócający',
    'Mixed': 'Mieszany',
    'Exploitive': 'Eksploatacyjny'
}

filtered_df.loc[:, 'event_type'] = filtered_df['event_type'].map(event_type_dict).fillna(filtered_df['event_type'])


motive_dict = {
    'Undetermined': 'Nieokreślony',
    'Protest': 'Protest',
    'Financial': 'Finansowy',
    'Political-Espionage': 'Polityczno-szpiegowski',
    'Sabotage': 'Sabotaż',
    'Espionage': 'Szpiegostwo',
    'Industrial-Espionage': 'Szpiegostwo przemysłowe',
    'Personal Attack': 'Atak osobisty',
    'Protest;Political-Espionage': 'Protest; Polityczno-szpiegowski',
    'Protest,Financial': 'Protest, Finansowy'
}

filtered_df.loc[:, 'motive'] = filtered_df['motive'].map(motive_dict).fillna(filtered_df['motive'])


country_codes = {
    'Afghanistan': 'AF',
    'Albania': 'AL',
    'Algeria': 'DZ',
    'American Samoa': 'AS',
    'Andorra': 'AD',
    'Angola': 'AO',
    'Antarctica': 'AQ',
    'Argentina': 'AR',
    'Armenia': 'AM',
    'Australia': 'AU',
    'Austria': 'AT',
    'Azerbaijan': 'AZ',
    'Bahamas': 'BS',
    'Bahrain': 'BH',
    'Bangladesh': 'BD',
    'Barbados': 'BB',
    'Belarus': 'BY',
    'Belgium': 'BE',
    'Bermuda': 'BM',
    'Bolivia (Plurinational State of)': 'BO',
    'Bonaire, Sint Eustatius and Saba': 'BQ',
    'Bosnia and Herzegovina': 'BA',
    'Brazil': 'BR',
    'Bulgaria': 'BG',
    'Cabo Verde': 'CV',
    'Cambodia': 'KH',
    'Canada': 'CA',
    'Cayman Islands': 'KY',
    'Chile': 'CL',
    'China': 'CN',
    'Colombia': 'CO',
    'Costa Rica': 'CR',
    'Croatia': 'HR',
    'Cuba': 'CU',
    'Cyprus': 'CY',
    'Czechia': 'CZ',
    'Denmark': 'DK',
    'Dominican Republic': 'DO',
    'Ecuador': 'EC',
    'Egypt': 'EG',
    'El Salvador': 'SV',
    'Estonia': 'EE',
    'Ethiopia': 'ET',
    'Fiji': 'FJ',
    'Finland': 'FI',
    'France': 'FR',
    'French Guiana': 'GF',
    'Gabon': 'GA',
    'Georgia': 'GE',
    'Germany': 'DE',
    'Ghana': 'GH',
    'Gibraltar': 'GI',
    'Greece': 'GR',
    'Greenland': 'GL',
    'Guadeloupe': 'GP',
    'Guam': 'GU',
    'Guatemala': 'GT',
    'Holy See': 'VA',
    'Hong Kong': 'HK',
    'Hungary': 'HU',
    'Iceland': 'IS',
    'India': 'IN',
    'Indonesia': 'ID',
    'Iran (Islamic Republic of)': 'IR',
    'Iraq': 'IQ',
    'Ireland': 'IE',
    'Isle of Man': 'IM',
    'Israel': 'IL',
    'Italy': 'IT',
    'Jamaica': 'JM',
    'Japan': 'JP',
    'Jordan': 'JO',
    'Kazakhstan': 'KZ',
    'Kenya': 'KE',
    'Kiribati': 'KI',
    "Korea (the Democratic People's Republic of)": 'KP',
    'Korea (the Republic of)': 'KR',
    'Kuwait': 'KW',
    "Lao People's Democratic Republic": 'LA',
    'Latvia': 'LV',
    'Lebanon': 'LB',
    'Lesotho': 'LS',
    'Libya': 'LY',
    'Liechtenstein': 'LI',
    'Lithuania': 'LT',
    'Luxembourg': 'LU',
    'Malawi': 'MW',
    'Malaysia': 'MY',
    'Maldives': 'MV',
    'Mali': 'ML',
    'Malta': 'MT',
    'Mexico': 'MX',
    'Moldova (the Republic of)': 'MD',
    'Monaco': 'MC',
    'Mongolia': 'MN',
    'Montenegro': 'ME',
    'Morocco': 'MA',
    'Myanmar': 'MM',
    'Namibia': 'NA',
    'Nauru': 'NR',
    'Nepal': 'NP',
    'Netherlands': 'NL',
    'New Zealand': 'NZ',
    'Nicaragua': 'NI',
    'Nigeria': 'NG',
    'Norway': 'NO',
    'Oman': 'OM',
    'Pakistan': 'PK',
    'Palau': 'PW',
    'Palestine, State of': 'PS',
    'Panama': 'PA',
    'Papua New Guinea': 'PG',
    'Paraguay': 'PY',
    'Peru': 'PE',
    'Philippines': 'PH',
    'Poland': 'PL',
    'Portugal': 'PT',
    'Puerto Rico': 'PR',
    'Qatar': 'QA',
    'Republic of North Macedonia': 'MK',
    'Romania': 'RO',
    'Russian Federation': 'RU',
    'Rwanda': 'RW',
    'Saint Vincent and the Grenadines': 'VC',
    'Saudi Arabia': 'SA',
    'Senegal': 'SN',
    'Serbia': 'RS',
    'Seychelles': 'SC',
    'Sierra Leone': 'SL',
    'Singapore': 'SG',
    'Slovakia': 'SK',
    'Slovenia': 'SI',
    'South Africa': 'ZA',
    'Spain': 'ES',
    'Sri Lanka': 'LK',
    'Sudan': 'SD',
    'Sweden': 'SE',
    'Switzerland': 'CH',
    'Syrian Arab Republic': 'SY',
    'Taiwan (Province of China)': 'TW',
    'Tajikistan': 'TJ',
    'Tanzania, United Republic of': 'TZ',
    'Thailand': 'TH',
    'Togo': 'TG',
    'Tonga': 'TO',
    'Trinidad and Tobago': 'TT',
    'Tunisia': 'TN',
    'Turkey': 'TR',
    'Turkmenistan': 'TM',
    'Uganda': 'UG',
    'Ukraine': 'UA',
    'United Arab Emirates': 'AE',
    'United Kingdom of Great Britain and Northern Ireland': 'GB',
    'United States of America': 'US',
    'Uruguay': 'UY',
    'Uzbekistan': 'UZ',
    'Vanuatu': 'VU',
    'Venezuela (Bolivarian Republic of)': 'VE',
    'Viet Nam': 'VN',
    'Yemen': 'YE',
    'Zambia': 'ZM',
    'Zimbabwe': 'ZW'
}

country_names_pl = {
    'Afghanistan': 'Afganistan',
    'Albania': 'Albania',
    'Algeria': 'Algieria',
    'American Samoa': 'Samoa Amerykańskie',
    'Andorra': 'Andora',
    'Angola': 'Angola',
    'Antarctica': 'Antarktyka',
    'Argentina': 'Argentyna',
    'Armenia': 'Armenia',
    'Australia': 'Australia',
    'Austria': 'Austria',
    'Azerbaijan': 'Azerbejdżan',
    'Bahamas': 'Bahamy',
    'Bahrain': 'Bahrajn',
    'Bangladesh': 'Bangladesz',
    'Barbados': 'Barbados',
    'Belarus': 'Białoruś',
    'Belgium': 'Belgia',
    'Bermuda': 'Bermudy',
    'Bolivia (Plurinational State of)': 'Boliwia',
    'Bonaire, Sint Eustatius and Saba': 'Bonaire, Sint Eustatius i Saba',
    'Bosnia and Herzegovina': 'Bośnia i Hercegowina',
    'Brazil': 'Brazylia',
    'Bulgaria': 'Bułgaria',
    'Cabo Verde': 'Republika Zielonego Przylądka',
    'Cambodia': 'Kambodża',
    'Canada': 'Kanada',
    'Cayman Islands': 'Kajmany',
    'Chile': 'Chile',
    'China': 'Chiny',
    'Colombia': 'Kolumbia',
    'Costa Rica': 'Kostaryka',
    'Croatia': 'Chorwacja',
    'Cuba': 'Kuba',
    'Cyprus': 'Cypr',
    'Czechia': 'Czechy',
    'Denmark': 'Dania',
    'Dominican Republic': 'Republika Dominikany',
    'Ecuador': 'Ekwador',
    'Egypt': 'Egipt',
    'El Salvador': 'Salwador',
    'Estonia': 'Estonia',
    'Ethiopia': 'Etiopia',
    'Fiji': 'Fidżi',
    'Finland': 'Finlandia',
    'France': 'Francja',
    'French Guiana': 'Gujana Francuska',
    'Gabon': 'Gabon',
    'Georgia': 'Gruzja',
    'Germany': 'Niemcy',
    'Ghana': 'Ghana',
    'Gibraltar': 'Gibraltar',
    'Greece': 'Grecja',
    'Greenland': 'Grenlandia',
    'Guadeloupe': 'Gwadelupa',
    'Guam': 'Guam',
    'Guatemala': 'Gwatemala',
    'Holy See': 'Stolica Apostolska',
    'Hong Kong': 'Hongkong',
    'Hungary': 'Węgry',
    'Iceland': 'Islandia',
    'India': 'Indie',
    'Indonesia': 'Indonezja',
    'Iran (Islamic Republic of)': 'Iran',
    'Iraq': 'Irak',
    'Ireland': 'Irlandia',
    'Isle of Man': 'Wyspa Man',
    'Israel': 'Izrael',
    'Italy': 'Włochy',
    'Jamaica': 'Jamajka',
    'Japan': 'Japonia',
    'Jordan': 'Jordania',
    'Kazakhstan': 'Kazachstan',
    'Kenya': 'Kenia',
    'Kiribati': 'Kiribati',
    "Korea (the Democratic People's Republic of)": 'Korea Północna',
    'Korea (the Republic of)': 'Korea Południowa',
    'Kuwait': 'Kuwejt',
    "Lao People's Democratic Republic": 'Laos',
    'Latvia': 'Łotwa',
    'Lebanon': 'Liban',
    'Lesotho': 'Lesotho',
    'Libya': 'Libia',
    'Liechtenstein': 'Liechtenstein',
    'Lithuania': 'Litwa',
    'Luxembourg': 'Luksemburg',
    'Malawi': 'Malawi',
    'Malaysia': 'Malezja',
    'Maldives': 'Malediwy',
    'Mali': 'Mali',
    'Malta': 'Malta',
    'Mexico': 'Meksyk',
    'Moldova (the Republic of)': 'Mołdawia',
    'Monaco': 'Monako',
    'Mongolia': 'Mongolia',
    'Montenegro': 'Czarnogóra',
    'Morocco': 'Maroko',
    'Myanmar': 'Mjanma',
    'Namibia': 'Namibia',
    'Nauru': 'Nauru',
    'Nepal': 'Nepal',
    'Netherlands': 'Holandia',
    'New Zealand': 'Nowa Zelandia',
    'Nicaragua': 'Nikaragua',
    'Nigeria': 'Nigeria',
    'Norway': 'Norwegia',
    'Oman': 'Oman',
    'Pakistan': 'Pakistan',
    'Palau': 'Palau',
    'Palestine, State of': 'Palestyna',
    'Panama': 'Panama',
    'Papua New Guinea': 'Papua-Nowa Gwinea',
    'Paraguay': 'Paragwaj',
    'Peru': 'Peru',
    'Philippines': 'Filipiny',
    'Poland': 'Polska',
    'Portugal': 'Portugalia',
    'Puerto Rico': 'Portoryko',
    'Qatar': 'Katar',
    'Republic of North Macedonia': 'Macedonia Północna',
    'Romania': 'Rumunia',
    'Russian Federation': 'Rosja',
    'Rwanda': 'Rwanda',
    'Saint Vincent and the Grenadines': 'Saint Vincent i Grenadyny',
    'Saudi Arabia': 'Arabia Saudyjska',
    'Senegal': 'Senegal',
    'Serbia': 'Serbia',
    'Seychelles': 'Seszele',
    'Sierra Leone': 'Sierra Leone',
    'Singapore': 'Singapur',
    'Slovakia': 'Słowacja',
    'Slovenia': 'Słowenia',
    'South Africa': 'Południowa Afryka',
    'Spain': 'Hiszpania',
    'Sri Lanka': 'Sri Lanka',
    'Sudan': 'Sudan',
    'Sweden': 'Szwecja',
    'Switzerland': 'Szwajcaria',
    'Syrian Arab Republic': 'Syria',
    'Taiwan (Province of China)': 'Tajwan',
    'Tajikistan': 'Tadżykistan',
    'Tanzania, United Republic of': 'Tanzania',
    'Thailand': 'Tajlandia',
    'Togo': 'Togo',
    'Tonga': 'Tonga',
    'Trinidad and Tobago': 'Trynidad i Tobago',
    'Tunisia': 'Tunezja',
    'Turkey': 'Turcja',
    'Turkmenistan': 'Turkmenistan',
    'Uganda': 'Uganda',
    'Ukraine': 'Ukraina',
    'United Arab Emirates': 'Zjednoczone Emiraty Arabskie',
    'United Kingdom of Great Britain and Northern Ireland': 'Wielka Brytania',
    'United States of America': 'Stany Zjednoczone',
    'Uruguay': 'Urugwaj',
    'Uzbekistan': 'Uzbekistan',
    'Vanuatu': 'Vanuatu',
    'Venezuela (Bolivarian Republic of)': 'Wenezuela',
    'Viet Nam': 'Wietnam',
    'Yemen': 'Jemen',
    'Zambia': 'Zambia',
    'Zimbabwe': 'Zimbabwe'
}


filtered_df.head()
# Out:
#                slug  event_date                       actor  actor_type  \
# 0  babb843cbce5db9e  2023-12-31                Undetermined    Criminal
# 1  581e011d5c37c281  2023-12-31  Belarusian Cyber-Partisans  Hacktivist
# 2  fa79c150aac3cf77  2023-12-30                  INC Ransom    Criminal
# 3  4d12747a4dd52156  2023-12-30                     Irleaks    Criminal
# 4  1079752e8fe90b4d  2023-12-29                Undetermined    Criminal
#
#                           organization  industry_code  \
# 0         Radioactive Waste Management             56
# 1                                BelTA             51
# 2             Xerox Business Solutions             56
# 3                            SnappFood             72
# 4  Memorial University of Newfoundland             61
#
#                                             industry        motive  \
# 0  Administrative and Support and Waste Managemen...  Nieokreślony
# 1                                        Information       Protest
# 2  Administrative and Support and Waste Managemen...     Finansowy
# 3                    Accommodation and Food Services     Finansowy
# 4                               Educational Services     Finansowy
#
#      event_type                       event_subtype  \
# 0  Nieokreślony                        Undetermined
# 1    Dysruptowy                        Undetermined
# 2      Mieszany  Exploitation of Application Server
# 3      Mieszany  Exploitation of Application Server
# 4    Dysruptowy                        Undetermined
#
#                                          description  \
# 0  Threat actors try to break into Radioactive Wa...
# 1  Belarusian hacktivists from the Belarusian Cyb...
# 2  The U.S. division of Xerox Business Solutions ...
# 3  Irleaks claims to have broken into the systems...
# 4  Memorial University of Newfoundland (MUN) is h...
#
#                                           source_url  \
# 0  https://www.theguardian.com/business/2023/dec/...
# 1  https://www.bankinfosecurity.com/hacktivists-s...
# 2  https://www.bleepingcomputer.com/news/security...
# 3  https://www.darkreading.com/cyberattacks-data-...
# 4  https://www.bleepingcomputer.com/news/security...
#
#                                              country actor_country
# 0  United Kingdom of Great Britain and Northern I...  Nieokreślony
# 1                                            Belarus      Białoruś
# 2                           United States of America  Nieokreślony
# 3                         Iran (Islamic Republic of)  Nieokreślony
# 4                                             Canada  Nieokreślony

# %%
import folium
import pandas as pd
from geopy.geocoders import Nominatim
import time
from collections import Counter

geolocator = Nominatim(user_agent="bezpieczni-app", timeout=10)

map = folium.Map(location=[0, 0], zoom_start=2, tiles='CartoDB dark_matter')

# Unikalne kraje z kolumny 'country'
unique_countries = filtered_df['country'].unique()

# Dodaj punkty do mapy na podstawie danych z ramki danych
for country in unique_countries:
    try:
        country_code = country_codes.get(country, 'brak kodu')
        location = geolocator.geocode(country, country_codes=country_code)
        country_polish = country_names_pl.get(country, 'Tłumaczenie niedostępne')
        if location:
            # Filtruj dane dla danego kraju
            country_data =filtered_df[filtered_df['country'] == country]
            # Zlicz typy wydarzeń według kraju
            event_type_counts = Counter(country_data['event_type'])
            # Przygotuj tekst do popup
            popup_text = "<br>".join([f"{event_type}: {count}" for event_type, count in event_type_counts.items()])
            folium.Marker(
                [location.latitude, location.longitude], 
                popup=f"{country_polish} - typ ataku:<br>{popup_text}"
            ).add_to(map)
    except Exception as e:
        print(f"Could not geocode {country}: {e}")
    print(country_code)
    print(country)

# Zapisz mapę do pliku HTML
map.save('../static/map2/map-type.html')
map
# Out:
# GB
# United Kingdom of Great Britain and Northern Ireland
# BY
# Belarus
# US
# United States of America
# IR
# Iran (Islamic Republic of)
# CA
# Canada
# IN
# India
# AU
# Australia
# IL
# Israel
# TT
# Trinidad and Tobago
# DE
# Germany
# SE
# Sweden
# NZ
# New Zealand
# AL
# Albania
# JO
# Jordan
# RU
# Russian Federation
# FR
# France
# UA
# Ukraine
# brak kodu
# Undetermined
# NP
# Nepal
# PS
# Palestine, State of
# EE
# Estonia
# BR
# Brazil
# IT
# Italy
# SC
# Seychelles
# IE
# Ireland
# LS
# Lesotho
# LT
# Lithuania
# TH
# Thailand
# NI
# Nicaragua
# KR
# Korea (the Republic of)
# PH
# Philippines
# EG
# Egypt
# SD
# Sudan
# TZ
# Tanzania, United Republic of
# CN
# China
# NL
# Netherlands
# JP
# Japan
# SI
# Slovenia
# SG
# Singapore
# NG
# Nigeria
# MA
# Morocco
# BH
# Bahrain
# ZA
# South Africa
# CH
# Switzerland
# TR
# Turkey
# TW
# Taiwan (Province of China)
# BD
# Bangladesh
# GR
# Greece
# PK
# Pakistan
# VN
# Viet Nam
# AZ
# Azerbaijan
# RO
# Romania
# PT
# Portugal
# ES
# Spain
# KH
# Cambodia
# MX
# Mexico
# CL
# Chile
# FI
# Finland
# DK
# Denmark
# AT
# Austria
# NO
# Norway
# IQ
# Iraq
# HK
# Hong Kong
# BM
# Bermuda
# KW
# Kuwait
# DO
# Dominican Republic
# CO
# Colombia
# LK
# Sri Lanka
# CZ
# Czechia
# PL
# Poland
# BE
# Belgium
# RS
# Serbia
# SV
# El Salvador
# EC
# Ecuador
# AR
# Argentina
# ID
# Indonesia
# KE
# Kenya
# VC
# Saint Vincent and the Grenadines
# MY
# Malaysia
# MT
# Malta
# ML
# Mali
# JM
# Jamaica
# KY
# Cayman Islands
# HR
# Croatia
# GT
# Guatemala
# VE
# Venezuela (Bolivarian Republic of)
# CY
# Cyprus
# PA
# Panama
# CR
# Costa Rica
# PR
# Puerto Rico
# PE
# Peru
# TO
# Tonga
# UY
# Uruguay
# SK
# Slovakia
# LV
# Latvia
# MD
# Moldova (the Republic of)
# CU
# Cuba
# AE
# United Arab Emirates
# BB
# Barbados
# VA
# Holy See
# MV
# Maldives
# GP
# Guadeloupe
# BQ
# Bonaire, Sint Eustatius and Saba
# TG
# Togo
# SA
# Saudi Arabia
# VU
# Vanuatu
# BG
# Bulgaria
# HU
# Hungary
# MM
# Myanmar
# PY
# Paraguay
# KZ
# Kazakhstan
# GH
# Ghana
# BA
# Bosnia and Herzegovina
# BO
# Bolivia (Plurinational State of)
# ME
# Montenegro
# AS
# American Samoa
# KI
# Kiribati
# LU
# Luxembourg
# GL
# Greenland
# ZM
# Zambia
# NR
# Nauru
# GI
# Gibraltar
# GF
# French Guiana
# LB
# Lebanon
# QA
# Qatar
# KP
# Korea (the Democratic People's Republic of)
# AD
# Andorra
# AO
# Angola
# PG
# Papua New Guinea
# AF
# Afghanistan
# GE
# Georgia
# FJ
# Fiji
# OM
# Oman
# MN
# Mongolia
# CV
# Cabo Verde
# UG
# Uganda
# MK
# Republic of North Macedonia
# DZ
# Algeria
# AM
# Armenia
# RW
# Rwanda
# SL
# Sierra Leone
# ET
# Ethiopia
# IM
# Isle of Man
# UZ
# Uzbekistan
# TM
# Turkmenistan
# LI
# Liechtenstein
# BS
# Bahamas
# YE
# Yemen
# ZW
# Zimbabwe
# GA
# Gabon
# AQ
# Antarctica
# SY
# Syrian Arab Republic
# MC
# Monaco
# LY
# Libya
# MW
# Malawi
# TN
# Tunisia
# SN
# Senegal
# IS
# Iceland
# LA
# Lao People's Democratic Republic
# NA
# Namibia
# GU
# Guam
# PW
# Palau
# TJ
# Tajikistan
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae37b62b0099f355bf72545f740d5f86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae37b62b0099f355bf72545f740d5f86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae37b62b0099f355bf72545f740d5f86 = L.map(
#                 &quot;map_ae37b62b0099f355bf72545f740d5f86&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd2ac3cf520f936acb201bad65e13a3d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fd2ac3cf520f936acb201bad65e13a3d.addTo(map_ae37b62b0099f355bf72545f740d5f86);
#
#
#             var marker_b106536f33531bc312a16c1880549bbe = L.marker(
#                 [54.7023545, -3.2765753],
#                 {}
#             ).addTo(map_ae37b62b0099f355bf72545f740d5f86);
#
#
#         var popup_ab23886948302b568239943365cd7b9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7433371485cd28cbbe3c1b8727c01f2 = $(`&lt;div id=&quot;html_e7433371485cd28cbbe3c1b8727c01f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wielka Brytania - typ ataku:&lt;br&gt;Nieokreślony: 19&lt;br&gt;Mieszany: 153&lt;br&gt;Dysruptowy: 196&lt;br&gt;Eksploatacyjny: 361&lt;/div&gt;`)[0];
#                 popup_ab23886948302b568239943365cd7b9f.setContent(html_e7433371485cd28cbbe3c1b8727c01f2);
#
#
#
#         marker_b106536f33531bc312a16c1880549bbe.bindPopup(popup_ab23886948302b568239943365cd7b9f)
#         ;
#
#
#
#
#             var marker_94ebc9c40c7909516206792d3e36bbe1 = L.marker(
#                 [53.4250605, 27.6971358],
#                 {}
#             ).addTo(map_ae37b62b0099f355bf72545f740d5f86);
#
#
#         var popup_f88d3c97d616cfa8efdc570c786c7649 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02658188743c98d8bd0226189f867e06 = $(`&lt;div id=&quot;html_02658188743c98d8bd0226189f867e06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Białoruś - typ ataku:&lt;br&gt;Dysruptowy: 7&lt;br&gt;Mieszany: 3&lt;br&gt;Eksploatacyjny: 19&lt;/div&gt;`)[0];
#                 popup_f88d3c97d616cfa8efdc570c786c7649.setContent(html_02658188743c98d8bd0226189f867e06);
#
#
#
#         marker_94ebc9c40c7909516206792d3e36bbe1.bindPopup(popup_f88d3c97d616cfa8efdc570c786c7649)
#         ;
#
#
#
#
#             var marker_0c3c38233646ad7d9464c8be40764972 = L.marker(
#                 [39.7837304, -100.445882],
#                 {}
#             ).addTo(map_ae37b62b0099f355bf72545f740d5f86);
#
#
#         var popup_3d9d4bfd61a3baae6fd8994d2812d564 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bed56f8fe160b2d003f720f616e2eec9 = $(`&lt;div id=&quot;html_bed56f8fe160b2d003f720f616e2eec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stany Zjednoczone - typ ataku:&lt;br&gt;Mieszany: 1217&lt;br&gt;Eksploatacyjny: 3729&lt;br&gt;Nieokreślony: 67&lt;br&gt;Dysruptowy: 1466&lt;/div&gt;`)[0];
#                 popup_3d9d4bfd61a3baae6fd8994d2812d564.setContent(html_bed56f8fe160b2d003f720f616e2eec9);
#
#
#
#         marker_0c3c38233646ad7d9464c8be40764972.bindPopup(popup_3d9d4bfd61a3baae6fd8994d2812d564)
#         ;
#
#
#
#
#             var marker_4df7d5d16ab46acd6f52c770bdc26b66 = L.marker(
#                 [32.6475314, 54.5643516],
#                 {}
#             ).addTo(map_ae37b62b0099f355bf72545f740d5f86);
#
#
#         var popup_26da87294f904f81b1bf0abd23061f0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fd13ca9296a3a05c6677d9d9c17b173 = $(`&lt;div id=&quot;html_8fd13ca9296a3a05c6677d9d9c17b173&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Iran - typ ataku:&lt;br&gt;Mieszany: 3&lt;br&gt;Eksploatacyjny: 23&lt;br&gt;Dysruptowy: 27&lt;/div&gt;`)[0];
#                 popup_26da87294f904f81b1bf0abd23061f0a.setContent(html_8fd13ca9296a3a05c6677d9d9c17b173);
#
#
#
#         marker_4df7d5d16ab46acd6f52c770bdc26b66.bindPopup(popup_26da87294f904f81b1bf0abd23061f0a)
#         ;
#
#
#
#
#             var marker_52f2125af6507b5afa9d9c32f4cd0253 = L.marker(
#                 [61.0666922, -107.991707],
#                 {}
#             ).addTo(map_ae37b62b0099f355bf72545f740d5f86);
#
#
#         var popup_7549b35cd0ac07f667d99c31a40a004f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7fd7638b66bb1d8abd5196ceb104563 = $(`&lt;div id=&quot;html_a7fd7638b66bb1d8abd5196ceb104563&quot; style=&quot;width: 100.0%

# %%
for country in unique_countries:
    try:
        country_code = country_codes.get(country, 'brak kodu')
        location = geolocator.geocode(country, country_codes=country_code)
        country_polish = country_names_pl.get(country, 'Tłumaczenie niedostępne')
        if location:
            # Filtruj dane dla danego kraju
            country_data =filtered_df[filtered_df['country'] == country]
            # Zlicz typy wydarzeń według kraju
            motive_counts = Counter(country_data['motive'])
            # Przygotuj tekst do popup
            popup_text = "<br>".join([f"{motive}: {count}" for motive, count in motive_counts.items()])
            folium.Marker(
                [location.latitude, location.longitude], 
                popup=f"{country_polish} - motyw ataku:<br>{popup_text}"
            ).add_to(map)
    except Exception as e:
        print(f"Could not geocode {country}: {e}")
    print(country_code)
    print(country)

# Zapisz mapę do pliku HTML
map.save('../static/map2/map-motive.html')
map
# Out:
# GB
# United Kingdom of Great Britain and Northern Ireland
# BY
# Belarus
# US
# United States of America
# IR
# Iran (Islamic Republic of)
# CA
# Canada
# IN
# India
# AU
# Australia
# IL
# Israel
# TT
# Trinidad and Tobago
# DE
# Germany
# SE
# Sweden
# NZ
# New Zealand
# AL
# Albania
# JO
# Jordan
# RU
# Russian Federation
# FR
# France
# UA
# Ukraine
# brak kodu
# Undetermined
# NP
# Nepal
# PS
# Palestine, State of
# EE
# Estonia
# BR
# Brazil
# IT
# Italy
# SC
# Seychelles
# IE
# Ireland
# LS
# Lesotho
# LT
# Lithuania
# TH
# Thailand
# NI
# Nicaragua
# KR
# Korea (the Republic of)
# PH
# Philippines
# EG
# Egypt
# SD
# Sudan
# TZ
# Tanzania, United Republic of
# CN
# China
# NL
# Netherlands
# JP
# Japan
# SI
# Slovenia
# SG
# Singapore
# NG
# Nigeria
# MA
# Morocco
# BH
# Bahrain
# ZA
# South Africa
# CH
# Switzerland
# TR
# Turkey
# TW
# Taiwan (Province of China)
# BD
# Bangladesh
# GR
# Greece
# PK
# Pakistan
# VN
# Viet Nam
# AZ
# Azerbaijan
# RO
# Romania
# PT
# Portugal
# ES
# Spain
# KH
# Cambodia
# MX
# Mexico
# CL
# Chile
# FI
# Finland
# DK
# Denmark
# AT
# Austria
# NO
# Norway
# IQ
# Iraq
# HK
# Hong Kong
# BM
# Bermuda
# KW
# Kuwait
# DO
# Dominican Republic
# CO
# Colombia
# LK
# Sri Lanka
# CZ
# Czechia
# PL
# Poland
# BE
# Belgium
# RS
# Serbia
# SV
# El Salvador
# EC
# Ecuador
# AR
# Argentina
# ID
# Indonesia
# KE
# Kenya
# VC
# Saint Vincent and the Grenadines
# MY
# Malaysia
# MT
# Malta
# ML
# Mali
# JM
# Jamaica
# KY
# Cayman Islands
# HR
# Croatia
# GT
# Guatemala
# VE
# Venezuela (Bolivarian Republic of)
# CY
# Cyprus
# PA
# Panama
# CR
# Costa Rica
# PR
# Puerto Rico
# PE
# Peru
# TO
# Tonga
# UY
# Uruguay
# SK
# Slovakia
# LV
# Latvia
# MD
# Moldova (the Republic of)
# CU
# Cuba
# AE
# United Arab Emirates
# BB
# Barbados
# VA
# Holy See
# MV
# Maldives
# GP
# Guadeloupe
# BQ
# Bonaire, Sint Eustatius and Saba
# TG
# Togo
# SA
# Saudi Arabia
# VU
# Vanuatu
# BG
# Bulgaria
# HU
# Hungary
# MM
# Myanmar
# PY
# Paraguay
# KZ
# Kazakhstan
# GH
# Ghana
# BA
# Bosnia and Herzegovina
# BO
# Bolivia (Plurinational State of)
# ME
# Montenegro
# AS
# American Samoa
# KI
# Kiribati
# LU
# Luxembourg
# GL
# Greenland
# ZM
# Zambia
# NR
# Nauru
# GI
# Gibraltar
# GF
# French Guiana
# LB
# Lebanon
# QA
# Qatar
# KP
# Korea (the Democratic People's Republic of)
# AD
# Andorra
# AO
# Angola
# PG
# Papua New Guinea
# AF
# Afghanistan
# GE
# Georgia
# FJ
# Fiji
# OM
# Oman
# MN
# Mongolia
# CV
# Cabo Verde
# UG
# Uganda
# MK
# Republic of North Macedonia
# DZ
# Algeria
# AM
# Armenia
# RW
# Rwanda
# SL
# Sierra Leone
# ET
# Ethiopia
# IM
# Isle of Man
# UZ
# Uzbekistan
# TM
# Turkmenistan
# LI
# Liechtenstein
# BS
# Bahamas
# YE
# Yemen
# ZW
# Zimbabwe
# GA
# Gabon
# AQ
# Antarctica
# SY
# Syrian Arab Republic
# MC
# Monaco
# LY
# Libya
# MW
# Malawi
# TN
# Tunisia
# SN
# Senegal
# IS
# Iceland
# LA
# Lao People's Democratic Republic
# NA
# Namibia
# GU
# Guam
# PW
# Palau
# TJ
# Tajikistan
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02ef0ff7f7b8b221b28aefea570f8c95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02ef0ff7f7b8b221b28aefea570f8c95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02ef0ff7f7b8b221b28aefea570f8c95 = L.map(
#                 &quot;map_02ef0ff7f7b8b221b28aefea570f8c95&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1044083d2af441e2ad6240603997c163 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1044083d2af441e2ad6240603997c163.addTo(map_02ef0ff7f7b8b221b28aefea570f8c95);
#
#
#             var marker_62ac8b143edc293c18a1fbcf74e56c2e = L.marker(
#                 [54.7023545, -3.2765753],
#                 {}
#             ).addTo(map_02ef0ff7f7b8b221b28aefea570f8c95);
#
#
#         var popup_dfc08e0103d7cd4c04317cb435b7cc8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bb5c06264263ea6793b9a184cc3418e = $(`&lt;div id=&quot;html_0bb5c06264263ea6793b9a184cc3418e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wielka Brytania - typ ataku:&lt;br&gt;Nieokreślony: 19&lt;br&gt;Mieszany: 153&lt;br&gt;Dysruptowy: 196&lt;br&gt;Eksploatacyjny: 361&lt;/div&gt;`)[0];
#                 popup_dfc08e0103d7cd4c04317cb435b7cc8e.setContent(html_0bb5c06264263ea6793b9a184cc3418e);
#
#
#
#         marker_62ac8b143edc293c18a1fbcf74e56c2e.bindPopup(popup_dfc08e0103d7cd4c04317cb435b7cc8e)
#         ;
#
#
#
#
#             var marker_e0dd41bf958b03ef5a931bb3acdacabf = L.marker(
#                 [53.4250605, 27.6971358],
#                 {}
#             ).addTo(map_02ef0ff7f7b8b221b28aefea570f8c95);
#
#
#         var popup_6a81f43b843d8c5da7d590cb42164a10 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4d7a0bbedddcaa194cb4f6b2a5bc3c8 = $(`&lt;div id=&quot;html_f4d7a0bbedddcaa194cb4f6b2a5bc3c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Białoruś - typ ataku:&lt;br&gt;Dysruptowy: 7&lt;br&gt;Mieszany: 3&lt;br&gt;Eksploatacyjny: 19&lt;/div&gt;`)[0];
#                 popup_6a81f43b843d8c5da7d590cb42164a10.setContent(html_f4d7a0bbedddcaa194cb4f6b2a5bc3c8);
#
#
#
#         marker_e0dd41bf958b03ef5a931bb3acdacabf.bindPopup(popup_6a81f43b843d8c5da7d590cb42164a10)
#         ;
#
#
#
#
#             var marker_bef8be89ff05ac4d8142c0e27e4b01f0 = L.marker(
#                 [39.7837304, -100.445882],
#                 {}
#             ).addTo(map_02ef0ff7f7b8b221b28aefea570f8c95);
#
#
#         var popup_2480f2bba4842ccae0c20cdfbaf4c94e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee856b549788aa9d1df96af0f8a840a8 = $(`&lt;div id=&quot;html_ee856b549788aa9d1df96af0f8a840a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stany Zjednoczone - typ ataku:&lt;br&gt;Mieszany: 1217&lt;br&gt;Eksploatacyjny: 3729&lt;br&gt;Nieokreślony: 67&lt;br&gt;Dysruptowy: 1466&lt;/div&gt;`)[0];
#                 popup_2480f2bba4842ccae0c20cdfbaf4c94e.setContent(html_ee856b549788aa9d1df96af0f8a840a8);
#
#
#
#         marker_bef8be89ff05ac4d8142c0e27e4b01f0.bindPopup(popup_2480f2bba4842ccae0c20cdfbaf4c94e)
#         ;
#
#
#
#
#             var marker_bbca5f90a5938efbee0c31a94a0abf5d = L.marker(
#                 [32.6475314, 54.5643516],
#                 {}
#             ).addTo(map_02ef0ff7f7b8b221b28aefea570f8c95);
#
#
#         var popup_e6fb183251b876df4c1323cd15d12fa6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a13a45eb296a8a49ee6d33f1284133c0 = $(`&lt;div id=&quot;html_a13a45eb296a8a49ee6d33f1284133c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Iran - typ ataku:&lt;br&gt;Mieszany: 3&lt;br&gt;Eksploatacyjny: 23&lt;br&gt;Dysruptowy: 27&lt;/div&gt;`)[0];
#                 popup_e6fb183251b876df4c1323cd15d12fa6.setContent(html_a13a45eb296a8a49ee6d33f1284133c0);
#
#
#
#         marker_bbca5f90a5938efbee0c31a94a0abf5d.bindPopup(popup_e6fb183251b876df4c1323cd15d12fa6)
#         ;
#
#
#
#
#             var marker_98fe3e913fffc8428bc738e404cf2c30 = L.marker(
#                 [61.0666922, -107.991707],
#                 {}
#             ).addTo(map_02ef0ff7f7b8b221b28aefea570f8c95);
#
#
#         var popup_198662878e1c0ff0e6c4f377aa5888bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb0daabfae01cd92065f4afb7233d9cf = $(`&lt;div id=&quot;html_fb0daabfae01cd92065f4afb7233d9cf&quot; style=&quot;width: 100.0%

# %%
for country in unique_countries:
    try:
        country_code = country_codes.get(country, 'brak kodu')
        location = geolocator.geocode(country, country_codes=country_code)
        country_polish = country_names_pl.get(country, 'Tłumaczenie niedostępne')
        if location:
            # Filtruj dane dla danego kraju
            country_data =filtered_df[filtered_df['country'] == country]
            # Zlicz typy wydarzeń według kraju
            actor_country_counts = Counter(country_data['actor_country'])
            # Przygotuj tekst do popup
            popup_text = "<br>".join([f"{actor_country}: {count}" for actor_country, count in actor_country_counts.items()])
            folium.Marker(
                [location.latitude, location.longitude], 
                popup=f"{country_polish} - kraje atakujące:<br>{popup_text}"
            ).add_to(map)
    except Exception as e:
        print(f"Could not geocode {country}: {e}")
    print(country_code)
    print(country)

# Zapisz mapę do pliku HTML
map.save('../static/map2/map-actor-country.html')
map
# Out:
# GB
# United Kingdom of Great Britain and Northern Ireland
# BY
# Belarus
# US
# United States of America
# IR
# Iran (Islamic Republic of)
# CA
# Canada
# IN
# India
# AU
# Australia
# IL
# Israel
# TT
# Trinidad and Tobago
# DE
# Germany
# SE
# Sweden
# NZ
# New Zealand
# AL
# Albania
# JO
# Jordan
# RU
# Russian Federation
# FR
# France
# UA
# Ukraine
# brak kodu
# Undetermined
# NP
# Nepal
# PS
# Palestine, State of
# EE
# Estonia
# BR
# Brazil
# IT
# Italy
# SC
# Seychelles
# IE
# Ireland
# LS
# Lesotho
# LT
# Lithuania
# TH
# Thailand
# NI
# Nicaragua
# KR
# Korea (the Republic of)
# PH
# Philippines
# EG
# Egypt
# SD
# Sudan
# TZ
# Tanzania, United Republic of
# CN
# China
# NL
# Netherlands
# JP
# Japan
# SI
# Slovenia
# SG
# Singapore
# NG
# Nigeria
# MA
# Morocco
# BH
# Bahrain
# ZA
# South Africa
# CH
# Switzerland
# TR
# Turkey
# TW
# Taiwan (Province of China)
# BD
# Bangladesh
# GR
# Greece
# PK
# Pakistan
# VN
# Viet Nam
# AZ
# Azerbaijan
# RO
# Romania
# PT
# Portugal
# ES
# Spain
# KH
# Cambodia
# MX
# Mexico
# CL
# Chile
# FI
# Finland
# DK
# Denmark
# AT
# Austria
# NO
# Norway
# IQ
# Iraq
# HK
# Hong Kong
# BM
# Bermuda
# KW
# Kuwait
# DO
# Dominican Republic
# CO
# Colombia
# LK
# Sri Lanka
# CZ
# Czechia
# PL
# Poland
# BE
# Belgium
# RS
# Serbia
# SV
# El Salvador
# EC
# Ecuador
# AR
# Argentina
# ID
# Indonesia
# KE
# Kenya
# VC
# Saint Vincent and the Grenadines
# MY
# Malaysia
# MT
# Malta
# ML
# Mali
# JM
# Jamaica
# KY
# Cayman Islands
# HR
# Croatia
# GT
# Guatemala
# VE
# Venezuela (Bolivarian Republic of)
# CY
# Cyprus
# PA
# Panama
# CR
# Costa Rica
# PR
# Puerto Rico
# PE
# Peru
# TO
# Tonga
# UY
# Uruguay
# SK
# Slovakia
# LV
# Latvia
# MD
# Moldova (the Republic of)
# CU
# Cuba
# AE
# United Arab Emirates
# BB
# Barbados
# VA
# Holy See
# MV
# Maldives
# GP
# Guadeloupe
# BQ
# Bonaire, Sint Eustatius and Saba
# TG
# Togo
# SA
# Saudi Arabia
# VU
# Vanuatu
# BG
# Bulgaria
# HU
# Hungary
# MM
# Myanmar
# PY
# Paraguay
# KZ
# Kazakhstan
# GH
# Ghana
# BA
# Bosnia and Herzegovina
# BO
# Bolivia (Plurinational State of)
# ME
# Montenegro
# AS
# American Samoa
# KI
# Kiribati
# LU
# Luxembourg
# GL
# Greenland
# ZM
# Zambia
# NR
# Nauru
# GI
# Gibraltar
# GF
# French Guiana
# LB
# Lebanon
# QA
# Qatar
# KP
# Korea (the Democratic People's Republic of)
# AD
# Andorra
# AO
# Angola
# PG
# Papua New Guinea
# AF
# Afghanistan
# GE
# Georgia
# FJ
# Fiji
# OM
# Oman
# MN
# Mongolia
# CV
# Cabo Verde
# UG
# Uganda
# MK
# Republic of North Macedonia
# DZ
# Algeria
# AM
# Armenia
# RW
# Rwanda
# SL
# Sierra Leone
# ET
# Ethiopia
# IM
# Isle of Man
# UZ
# Uzbekistan
# TM
# Turkmenistan
# LI
# Liechtenstein
# BS
# Bahamas
# YE
# Yemen
# ZW
# Zimbabwe
# GA
# Gabon
# AQ
# Antarctica
# SY
# Syrian Arab Republic
# MC
# Monaco
# LY
# Libya
# MW
# Malawi
# TN
# Tunisia
# SN
# Senegal
# IS
# Iceland
# LA
# Lao People's Democratic Republic
# NA
# Namibia
# GU
# Guam
# PW
# Palau
# TJ
# Tajikistan
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_887d74bbdb1b7482463506d28017b936 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_887d74bbdb1b7482463506d28017b936&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_887d74bbdb1b7482463506d28017b936 = L.map(
#                 &quot;map_887d74bbdb1b7482463506d28017b936&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23bbad6756ea009861aa4cad5ee52c86 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_23bbad6756ea009861aa4cad5ee52c86.addTo(map_887d74bbdb1b7482463506d28017b936);
#
#
#             var marker_e0b469d16a2c0ed002a438121f9bf8c0 = L.marker(
#                 [54.7023545, -3.2765753],
#                 {}
#             ).addTo(map_887d74bbdb1b7482463506d28017b936);
#
#
#         var popup_9c7a5e5a47c79a4bef4f1be8cef282c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38aec9e3bc913e45889e1a3aed8c4878 = $(`&lt;div id=&quot;html_38aec9e3bc913e45889e1a3aed8c4878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wielka Brytania - typ ataku:&lt;br&gt;Nieokreślony: 19&lt;br&gt;Mieszany: 153&lt;br&gt;Dysruptowy: 196&lt;br&gt;Eksploatacyjny: 361&lt;/div&gt;`)[0];
#                 popup_9c7a5e5a47c79a4bef4f1be8cef282c4.setContent(html_38aec9e3bc913e45889e1a3aed8c4878);
#
#
#
#         marker_e0b469d16a2c0ed002a438121f9bf8c0.bindPopup(popup_9c7a5e5a47c79a4bef4f1be8cef282c4)
#         ;
#
#
#
#
#             var marker_81dcf0f639ddf6b8f914c4f6852ab569 = L.marker(
#                 [53.4250605, 27.6971358],
#                 {}
#             ).addTo(map_887d74bbdb1b7482463506d28017b936);
#
#
#         var popup_2b62242bd34fcb348f3ccaa7f7da5b5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_204e5336f5fac97f420cee165346725e = $(`&lt;div id=&quot;html_204e5336f5fac97f420cee165346725e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Białoruś - typ ataku:&lt;br&gt;Dysruptowy: 7&lt;br&gt;Mieszany: 3&lt;br&gt;Eksploatacyjny: 19&lt;/div&gt;`)[0];
#                 popup_2b62242bd34fcb348f3ccaa7f7da5b5c.setContent(html_204e5336f5fac97f420cee165346725e);
#
#
#
#         marker_81dcf0f639ddf6b8f914c4f6852ab569.bindPopup(popup_2b62242bd34fcb348f3ccaa7f7da5b5c)
#         ;
#
#
#
#
#             var marker_7540c6e06d32cb4263bf5c240293b251 = L.marker(
#                 [39.7837304, -100.445882],
#                 {}
#             ).addTo(map_887d74bbdb1b7482463506d28017b936);
#
#
#         var popup_43829c0acec397446dedc428aaeca8ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d65189de87b506e3637ec8f52ced4798 = $(`&lt;div id=&quot;html_d65189de87b506e3637ec8f52ced4798&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stany Zjednoczone - typ ataku:&lt;br&gt;Mieszany: 1217&lt;br&gt;Eksploatacyjny: 3729&lt;br&gt;Nieokreślony: 67&lt;br&gt;Dysruptowy: 1466&lt;/div&gt;`)[0];
#                 popup_43829c0acec397446dedc428aaeca8ff.setContent(html_d65189de87b506e3637ec8f52ced4798);
#
#
#
#         marker_7540c6e06d32cb4263bf5c240293b251.bindPopup(popup_43829c0acec397446dedc428aaeca8ff)
#         ;
#
#
#
#
#             var marker_cb43b07281479f32d02c74ed5829b8bc = L.marker(
#                 [32.6475314, 54.5643516],
#                 {}
#             ).addTo(map_887d74bbdb1b7482463506d28017b936);
#
#
#         var popup_3f9982933cba38a194954ef04d27c51c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7bf7bf4f293754b3a863300fcaa65b41 = $(`&lt;div id=&quot;html_7bf7bf4f293754b3a863300fcaa65b41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Iran - typ ataku:&lt;br&gt;Mieszany: 3&lt;br&gt;Eksploatacyjny: 23&lt;br&gt;Dysruptowy: 27&lt;/div&gt;`)[0];
#                 popup_3f9982933cba38a194954ef04d27c51c.setContent(html_7bf7bf4f293754b3a863300fcaa65b41);
#
#
#
#         marker_cb43b07281479f32d02c74ed5829b8bc.bindPopup(popup_3f9982933cba38a194954ef04d27c51c)
#         ;
#
#
#
#
#             var marker_446b14a1cdfe83c19e01e4c76ebd3f04 = L.marker(
#                 [61.0666922, -107.991707],
#                 {}
#             ).addTo(map_887d74bbdb1b7482463506d28017b936);
#
#
#         var popup_6a9454d6b214ddd99d18cdfef04af552 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37fe724507d5f543341ba211b699a7aa = $(`&lt;div id=&quot;html_37fe724507d5f543341ba211b699a7aa&quot; style=&quot;width: 100.0%

# %%
unique_countries = filtered_df['country'].nunique()
unique_countries
